# %%
import h5py

# %%
file_path = '../data/TrainSet_us101.mat'

# %%
with h5py.File(file_path, 'r') as f:
    def print_attrs(name, obj):
        print(name)
    f.visititems(print_attrs)
# Out:
# #refs#
# #refs#/0
# #refs#/00
# #refs#/01
# #refs#/02
# #refs#/03
# #refs#/04
# #refs#/05
# #refs#/06
# #refs#/07
# #refs#/08
# #refs#/09
# #refs#/0A
# #refs#/0B
# #refs#/0C
# #refs#/0D
# #refs#/0E
# #refs#/0F
# #refs#/0G
# #refs#/0H
# #refs#/0I
# #refs#/0J
# #refs#/0K
# #refs#/0L
# #refs#/0M
# #refs#/0N
# #refs#/0O
# #refs#/0P
# #refs#/0Q
# #refs#/0R
# #refs#/0S
# #refs#/0T
# #refs#/0U
# #refs#/0V
# #refs#/0W
# #refs#/0X
# #refs#/0Y
# #refs#/0Z
# #refs#/0ab
# #refs#/0b
# #refs#/0bb
# #refs#/0c
# #refs#/0cb
# #refs#/0d
# #refs#/0db
# #refs#/0e
# #refs#/0eb
# #refs#/0f
# #refs#/0fb
# #refs#/0g
# #refs#/0gb
# #refs#/0h
# #refs#/0hb
# #refs#/0i
# #refs#/0ib
# #refs#/0j
# #refs#/0k
# #refs#/0l
# #refs#/0m
# #refs#/0n
# #refs#/0o
# #refs#/0p
# #refs#/0q
# #refs#/0r
# #refs#/0s
# #refs#/0t
# #refs#/0u
# #refs#/0v
# #refs#/0w
# #refs#/0x
# #refs#/0y
# #refs#/0z
# #refs#/1
# #refs#/10
# #refs#/11
# #refs#/12
# #refs#/13
# #refs#/14
# #refs#/15
# #refs#/16
# #refs#/17
# #refs#/18
# #refs#/19
# ...
